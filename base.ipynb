# %%
import ultralytics

# %%
from ultralytics import YOLO

# %%
# !ls
# Out:
# base.ipynb  data

# %%
# !yolo task=detect mode=predict model=runs/detect/train2/weights/best.pt source='demo2.jpeg'
# Out:
# Ultralytics YOLOv8.1.38 🚀 Python-3.11.5 torch-2.2.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12001MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /media/varun/data/data science/yolotutorial/numberplatedetection/demo2.jpeg: 512x640 1 LicensePlate, 42.4ms
# Speed: 1.8ms preprocess, 42.4ms inference, 182.0ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=runs/detect/train2/weights/best.pt source='demo.mp4'
# Out:
# Ultralytics YOLOv8.1.38 🚀 Python-3.11.5 torch-2.2.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12001MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/631) /media/varun/data/data science/yolotutorial/numberplatedetection/demo.mp4: 416x640 1 LicensePlate, 45.9ms
# video 1/1 (frame 2/631) /media/varun/data/data science/yolotutorial/numberplatedetection/demo.mp4: 416x640 1 LicensePlate, 1.9ms
# video 1/1 (frame 3/631) /media/varun/data/data science/yolotutorial/numberplatedetection/demo.mp4: 416x640 1 LicensePlate, 1.9ms
# video 1/1 (frame 4/631) /media/varun/data/data science/yolotutorial/numberplatedetection/demo.mp4: 416x640 1 LicensePlate, 1.8ms
# video 1/1 (frame 5/631) /media/varun/data/data science/yolotutorial/numberplatedetection/demo.mp4: 416x640 1 LicensePlate, 2.0ms
# video 1/1 (frame 6/631) /media/varun/data/data science/yolotutorial/numberplatedetection/demo.mp4: 416x640 1 LicensePlate, 1.8ms
# ...
